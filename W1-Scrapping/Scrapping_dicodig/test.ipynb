# %%
import pandas as pd
data = pd.read_json('dicoding_data.json')

# %%
data
# Out:
#                                           Course Name Learning Hour Rating  \
# 0                 Belajar Analisis Data dengan Python        30 Jam   4,80
# 1            Belajar Tools Front-End Web Intermediate        65 Jam   4,85
# 2                      Belajar Dasar Manajemen Proyek        11 Jam   4,87
# 3       Belajar Pemrograman Fungsional dengan Haskell        20 Jam   4,92
# 4                      Belajar Penerapan Data Science        40 Jam   4,85
# ..                                                ...           ...    ...
# 70  Belajar Membangun LINE Front-end Framework (LIFF)        15 Jam   4,93
# 71                     Belajar Membangun LINE Chatbot        20 Jam   4,89
# 72  Simulasi Ujian Pendidik Level 1 (Google Certif...        19 Jam
# 73  Simulasi Ujian Pendidik Level 2 (Google Certif...        19 Jam
# 74  Simulasi Ujian Penilaian Keterampilan Pelatih ...        10 Jam
#
#                      Level                                            Summary  \
# ...
